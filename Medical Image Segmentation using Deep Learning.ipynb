# %% [markdown]
# # U-net for Brain Tumor Segmentation in MRI.
#
# This notebook contains the implementation of a neural network U-net for brain tumor segmentation in magnetic resonance images. The images and masks used in the training are available at this link: https://www.kaggle.com/datasets/mateuszbuda/lgg-mri-segmentation

# %% [markdown]
# * Problem definition

# %% [markdown]
# > Brain tumors represent a complex and serious condition that affects millions of individuals worldwide. The diagnosis of these tumors can be a challenging process, especially in cases of small or diffuse tumors. Imaging technology, such as magnetic resonance imaging (MRI), is an important tool for aiding in the diagnosis of brain tumors. However, image analysis can be time-consuming and requires specialized knowledge.

# %% [markdown]
# > ![image.png](data:image/png;base64,...)
#
# > Image available at: https://www.cityofhope.org/clinical-program/brain-tumors/brain-tumors-facts

# %% [markdown]
# * A possible solution

# %% [markdown]
# > In this context, the use of artificial intelligence (AI) algorithms emerges as a promising alternative to assist in the identification of brain tumors in MRI images. AI algorithms can be trained to identify specific patterns and features in medical data, aiding in the detection of tumors with greater accuracy and efficiency. Additionally, AI can be used to segment the tumors and classify them according to their degree of malignancy.
#
# > The use of AI algorithms, in conjunction with MRI imaging technology, can provide more accurate and rapid results in the identification and classification of brain tumors. This approach can be particularly useful in emergency situations, where a rapid and accurate diagnosis is essential for clinical decision-making. Moreover, the use of AI in the healthcare field can contribute to the improvement of treatment and care for patients with brain tumors. Therefore, the use of AI algorithms in the identification of brain tumors can have a significant impact on clinical practice, offering more accurate and efficient results for the diagnosis and treatment of these tumors.

# %% [markdown]
# > ![image.png](data:image/png;base64,...)
#
# > Image avaliable at: https://paperswithcode.com/task/tumor-segmentation

# %% [markdown]
# * The U-Net architecture

# %% [markdown]
# > The U-net architecture is a convolutional neural network that has been widely used in medical image segmentation tasks. Initially proposed for the segmentation of biological cell images, its application was extended to the segmentation of brain tumors in MRI images.
#
# > It consists of an encoder and a decoder, connected by a series of convolutional and pooling layers. The encoder is responsible for extracting features from the input image, while the decoder reconstructs the output segmentation map. The U-net also includes skip connections, which allow for the transfer of information from the encoder to the decoder, improving the accuracy of the segmentation. The number of layers and filters used in the U-net can be adjusted to optimize its performance for specific tasks.

# %% [markdown]
# > ![image.png](data:image/png;base64,...)
#
# > Image avaliable at: https://arxiv.org/pdf/1505.04597v1.pdf

# %% [markdown]
# # Data processing 🔍

# %% [markdown]
# As we are working with magnetic resonance images, it is very common for them to be in ".dcm", ".nii" or ".tif". For this reason, we need to pre-process the data before passing it to our neural network.

# %% [markdown]
# * Synchronizing the environment with Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# * Importing required libraries and modules

# %%
import os
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("ggplot")
# %matplotlib inline

import cv2
from tqdm import tqdm_notebook, tnrange
from glob import glob
from itertools import chain
from skimage.io import imread, imshow, concatenate_images
from skimage.transform import resize
from skimage.morphology import label
from skimage.color import rgb2gray
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras import Input
from tensorflow.keras.models import Model, load_model, save_model
from tensorflow.keras.layers import Input, Activation, BatchNormalization, Dropout, Lambda, Conv2D, Conv2DTranspose, MaxPooling2D, concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras import backend as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# Set Parameters to resize
im_width = 256
im_height = 256

# %% [markdown]
# * Saving image names and masks in arrays

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("mateuszbuda/lgg-mri-segmentation")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/lgg-mri-segmentation

# %%
train_files = []
mask_files = glob('/kaggle/input/lgg-mri-segmentation/kaggle_3m/*/*_mask*')

for i in mask_files:
    train_files.append(i.replace('_mask',''))

print(train_files[:10])
print(mask_files[:10])
# Out:
# ['/kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_56.tif', '/kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_8.tif', '/kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_34.tif', '/kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_33.tif', '/kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_43.tif', '/kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_39.tif', '/kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_7.tif', '/kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_31.tif', '/kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_6.tif', '/kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_38.tif']
# ['/kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_56_mask.tif', '/kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_8_mask.tif', '/kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_34_mask.tif', '/kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_33_mask.tif', '/kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_43_mask.tif', '/kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_39_mask.tif', '/kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_7_mask.tif', '/kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_31_mask.tif', '/kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_6_mask.tif', '/kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_38_mask.tif']

# %% [markdown]
# * Data visualization

# %%
#Lets plot some samples
rows,cols=5,5
fig=plt.figure(figsize=(10,10))
for i in range(1,rows*cols+1):
    fig.add_subplot(rows,cols,i)
    img_path=train_files[i]
    msk_path=mask_files[i]
    img=cv2.imread(img_path)
    img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    msk=cv2.imread(msk_path)
    plt.imshow(img)
    plt.imshow(msk,alpha=0.4)
plt.show()

# %% [markdown]
# * Defining training, validation, and testing sets.

# %%
df = pd.DataFrame(data={"filename": train_files, 'mask' : mask_files})
df_train, df_test = train_test_split(df,test_size = 0.1)
df_train, df_val = train_test_split(df_train,test_size = 0.2)
print(df_train.values.shape)
print(df_val.values.shape)
print(df_test.values.shape)
# Out:
# (2828, 2)
# (708, 2)
# (393, 2)

# %% [markdown]
# * Data pre-processing

# %%
# From: https://github.com/zhixuhao/unet/blob/master/data.py
def train_generator(data_frame, batch_size, aug_dict,
        image_color_mode="rgb",
        mask_color_mode="grayscale",
        image_save_prefix="image",
        mask_save_prefix="mask",
        save_to_dir=None,
        target_size=(256,256),
        seed=1):
    '''
    can generate image and mask at the same time use the same seed for
    image_datagen and mask_datagen to ensure the transformation for image
    and mask is the same if you want to visualize the results of generator,
    set save_to_dir = "your path"
    '''
    image_datagen = ImageDataGenerator(**aug_dict)
    mask_datagen = ImageDataGenerator(**aug_dict)

    image_generator = image_datagen.flow_from_dataframe(
        data_frame,
        x_col = "filename",
        class_mode = None,
        color_mode = image_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = image_save_prefix,
        seed = seed)

    mask_generator = mask_datagen.flow_from_dataframe(
        data_frame,
        x_col = "mask",
        class_mode = None,
        color_mode = mask_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = mask_save_prefix,
        seed = seed)

    train_gen = zip(image_generator, mask_generator)

    for (img, mask) in train_gen:
        img, mask = adjust_data(img, mask)
        yield (img,mask)

def adjust_data(img,mask):
    img = img / 255
    mask = mask / 255
    mask[mask > 0.5] = 1
    mask[mask <= 0.5] = 0

    return (img, mask)

# %% [markdown]
# * Metrics related to mask overlay on image

# %% [markdown]
# # Defining the architecture of the U-Net model 🧠

# %%
def unet(input_size=(256,256,3)):
    inputs = Input(input_size)

    conv1 = Conv2D(64, (3, 3), padding='same')(inputs)
    bn1 = Activation('relu')(conv1)
    conv1 = Conv2D(64, (3, 3), padding='same')(bn1)
    bn1 = BatchNormalization(axis=3)(conv1)
    bn1 = Activation('relu')(bn1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(bn1)

    conv2 = Conv2D(128, (3, 3), padding='same')(pool1)
    bn2 = Activation('relu')(conv2)
    conv2 = Conv2D(128, (3, 3), padding='same')(bn2)
    bn2 = BatchNormalization(axis=3)(conv2)
    bn2 = Activation('relu')(bn2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(bn2)

    conv3 = Conv2D(256, (3, 3), padding='same')(pool2)
    bn3 = Activation('relu')(conv3)
    conv3 = Conv2D(256, (3, 3), padding='same')(bn3)
    bn3 = BatchNormalization(axis=3)(conv3)
    bn3 = Activation('relu')(bn3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(bn3)

    conv4 = Conv2D(512, (3, 3), padding='same')(pool3)
    bn4 = Activation('relu')(conv4)
    conv4 = Conv2D(512, (3, 3), padding='same')(bn4)
    bn4 = BatchNormalization(axis=3)(conv4)
    bn4 = Activation('relu')(bn4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(bn4)

    conv5 = Conv2D(1024, (3, 3), padding='same')(pool4)
    bn5 = Activation('relu')(conv5)
    conv5 = Conv2D(1024, (3, 3), padding='same')(bn5)
    bn5 = BatchNormalization(axis=3)(conv5)
    bn5 = Activation('relu')(bn5)

    up6 = concatenate([Conv2DTranspose(512, (2, 2), strides=(2, 2), padding='same')(bn5), conv4], axis=3)
    conv6 = Conv2D(512, (3, 3), padding='same')(up6)
    bn6 = Activation('relu')(conv6)
    conv6 = Conv2D(512, (3, 3), padding='same')(bn6)
    bn6 = BatchNormalization(axis=3)(conv6)
    bn6 = Activation('relu')(bn6)

    up7 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(bn6), conv3], axis=3)
    conv7 = Conv2D(256, (3, 3), padding='same')(up7)
    bn7 = Activation('relu')(conv7)
    conv7 = Conv2D(256, (3, 3), padding='same')(bn7)
    bn7 = BatchNormalization(axis=3)(conv7)
    bn7 = Activation('relu')(bn7)

    up8 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(bn7), conv2], axis=3)
    conv8 = Conv2D(128, (3, 3), padding='same')(up8)
    bn8 = Activation('relu')(conv8)
    conv8 = Conv2D(128, (3, 3), padding='same')(bn8)
    bn8 = BatchNormalization(axis=3)(conv8)
    bn8 = Activation('relu')(bn8)

    up9 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(bn8), conv1], axis=3)
    conv9 = Conv2D(64, (3, 3), padding='same')(up9)
    bn9 = Activation('relu')(conv9)
    conv9 = Conv2D(64, (3, 3), padding='same')(bn9)
    bn9 = BatchNormalization(axis=3)(conv9)
    bn9 = Activation('relu')(bn9)

    conv10 = Conv2D(1, (1, 1), activation='sigmoid')(bn9)

    return Model(inputs=[inputs], outputs=[conv10])

# %%
model = unet()
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 256, 256,  │      1,792 │ input_layer[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 256, 256,  │          0 │ conv2d[0][0]      │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 256, 256,  │     36,928 │ activation[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 256, 256,  │        256 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 128, 128,  │          0 │ activation_1[0][… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 128, 128,  │     73,856 │ max_pooling2d[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 128, 128,  │          0 │ conv2d_2[0][0]    │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 128, 128,  │    147,584 │ activation_2[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        512 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 64, 64,    │          0 │ activation_3[0][… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 64, 64,    │    295,168 │ max_pooling2d_1[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 64, 64,    │          0 │ conv2d_4[0][0]    │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 64, 64,    │    590,080 │ activation_4[0][… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │      1,024 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 32, 32,    │          0 │ activation_5[0][… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 32, 32,    │  1,180,160 │ max_pooling2d_2[… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 32, 32,    │          0 │ conv2d_6[0][0]    │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 32, 32,    │  2,359,808 │ activation_6[0][… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      2,048 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 16, 16,    │          0 │ activation_7[0][… │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 16, 16,    │  4,719,616 │ max_pooling2d_3[… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 16, 16,    │          0 │ conv2d_8[0][0]    │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 16, 16,    │  9,438,208 │ activation_8[0][… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      4,096 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 32, 32,    │  2,097,664 │ activation_9[0][… │
# │ (Conv2DTranspose)   │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 1024)             │            │ conv2d_7[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 32, 32,    │  4,719,104 │ concatenate[0][0] │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 32, 32,    │          0 │ conv2d_10[0][0]   │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 32, 32,    │  2,359,808 │ activation_10[0]… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      2,048 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 64, 64,    │    524,544 │ activation_11[0]… │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 512)              │            │ conv2d_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 64, 64,    │  1,179,904 │ concatenate_1[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 64, 64,    │          0 │ conv2d_12[0][0]   │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 64, 64,    │    590,080 │ activation_12[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │      1,024 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 128, 128,  │    131,200 │ activation_13[0]… │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 128, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ conv2d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 128, 128,  │    295,040 │ concatenate_2[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 128, 128,  │          0 │ conv2d_14[0][0]   │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 128, 128,  │    147,584 │ activation_14[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        512 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 256, 256,  │     32,832 │ activation_15[0]… │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 256, 256,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 256, 256,  │     73,792 │ concatenate_3[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 256, 256,  │          0 │ conv2d_16[0][0]   │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 256, 256,  │     36,928 │ activation_16[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        256 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 256, 256,  │         65 │ activation_17[0]… │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 31,043,521 (118.42 MB)
#  Trainable params: 31,037,633 (118.40 MB)
#  Non-trainable params: 5,888 (23.00 KB)

# %% [markdown]
# # Training the model ⚙️

# %%
EPOCHS = 61
BATCH_SIZE = 32

# %%
# Defining training image transformations
train_generator_args = dict(rotation_range=0.2,
                            width_shift_range=0.05,
                            height_shift_range=0.05,
                            shear_range=0.05,
                            zoom_range=0.05,
                            horizontal_flip=True,
                            fill_mode='nearest')

# Creating training set using function train_generator() to separate into batches.
train_gen = train_generator(df_train, BATCH_SIZE,
                                train_generator_args,
                                target_size=(im_height, im_width))

test_gener = train_generator(df_val, BATCH_SIZE,
                                dict(),
                                target_size=(im_height, im_width))

# Defining the model with input_size and 3 channels
model = unet(input_size=(im_height, im_width, 3))

# Defining the optimizer
opt = tf.keras.optimizers.Adam(learning_rate=0.001)

# Setting callbacks
early_stop = EarlyStopping(monitor='val_loss', patience=10, mode='min', verbose=1)
callbacks = [ModelCheckpoint('unet_brain_mri_seg.keras', verbose=1, save_best_only=True), early_stop]

# Compiling the model
model.compile(optimizer=opt, loss=dice_coef_loss, metrics=["binary_accuracy", iou, dice_coef])

# # Saving history
# history = model.fit(train_gen,
#                     steps_per_epoch=int(len(df_train) / BATCH_SIZE),
#                     # steps_per_epoch = len(df_train) // BATCH_SIZE,
#                     epochs=EPOCHS,
#                     callbacks=callbacks,
#                     validation_data = test_gener,
#                     validation_steps=len(df_val) / BATCH_SIZE)

history = model.fit(
    train_gen,
    steps_per_epoch=len(df_train) // BATCH_SIZE,
    epochs=EPOCHS,
    callbacks=callbacks,
    validation_data=test_gener,
    validation_steps=len(df_val) // BATCH_SIZE
)
# Out:
# Found 2828 validated image filenames.
# Found 2828 validated image filenames.
# Epoch 1/61
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor_472']
# Received: inputs=Tensor(shape=(None, 256, 256, 3))
#   warnings.warn(msg)
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.8640 - dice_coef: 0.1234 - iou: 0.0683 - loss: -0.1234Found 708 validated image filenames.
# Found 708 validated image filenames.
#
# Epoch 1: val_loss improved from inf to -0.02333, saving model to unet_brain_mri_seg.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 209s 2s/step - binary_accuracy: 0.8649 - dice_coef: 0.1241 - iou: 0.0687 - loss: -0.1241 - val_binary_accuracy: 0.1918 - val_dice_coef: 0.0233 - val_iou: 0.0118 - val_loss: -0.0233
# Epoch 2/61
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.9892 - dice_coef: 0.3908 - iou: 0.2507 - loss: -0.3942
# Epoch 2: val_loss did not improve from -0.02333
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 231s 2s/step - binary_accuracy: 0.9892 - dice_coef: 0.3915 - iou: 0.2513 - loss: -0.3949 - val_binary_accuracy: 0.1130 - val_dice_coef: 0.0227 - val_iou: 0.0115 - val_loss: -0.0227
# Epoch 3/61
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.9923 - dice_coef: 0.5635 - iou: 0.4037 - loss: -0.5660
# Epoch 3: val_loss improved from -0.02333 to -0.54870, saving model to unet_brain_mri_seg.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 217s 2s/step - binary_accuracy: 0.9923 - dice_coef: 0.5640 - iou: 0.4041 - loss: -0.5664 - val_binary_accuracy: 0.9924 - val_dice_coef: 0.5283 - val_iou: 0.3733 - val_loss: -0.5487
# Epoch 4/61
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.9931 - dice_coef: 0.6365 - iou: 0.4787 - loss: -0.6342
# Epoch 4: val_loss improved from -0.54870 to -0.64559, saving model to unet_brain_mri_seg.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 163s 2s/step - binary_accuracy: 0.9931 - dice_coef: 0.6364 - iou: 0.4786 - loss: -0.6341 - val_binary_accuracy: 0.9916 - val_dice_coef: 0.6550 - val_iou: 0.4975 - val_loss: -0.6456
# Epoch 5/61
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.9932 - dice_coef: 0.6435 - iou: 0.4830 - loss: -0.6421
# Epoch 5: val_loss improved from -0.64559 to -0.66486, saving model to unet_brain_mri_seg.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 162s 2s/step - binary_accuracy: 0.9932 - dice_coef: 0.6436 - iou: 0.4831 - loss: -0.6423 - val_binary_accuracy: 0.9944 - val_dice_coef: 0.6732 - val_iou: 0.5207 - val_loss: -0.6649
# Epoch 6/61
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.9940 - dice_coef: 0.6756 - iou: 0.5195 - loss: -0.6810
# Epoch 6: val_loss did not improve from -0.66486
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 160s 2s/step - binary_accuracy: 0.9940 - dice_coef: 0.6755 - iou: 0.5194 - loss: -0.6808 - val_binary_accuracy: 0.9901 - val_dice_coef: 0.6476 - val_iou: 0.4835 - val_loss: -0.6418
# Epoch 7/61
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.9941 - dice_coef: 0.6820 - iou: 0.5258 - loss: -0.6784
# Epoch 7: val_loss improved from -0.66486 to -0.74395, saving model to unet_brain_mri_seg.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 206s 2s/step - binary_accuracy: 0.9941 - dice_coef: 0.6821 - iou: 0.5259 - loss: -0.6785 - val_binary_accuracy: 0.9953 - val_dice_coef: 0.7480 - val_iou: 0.6057 - val_loss: -0.7440
# Epoch 8/61
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.9946 - dice_coef: 0.6996 - iou: 0.5462 - loss: -0.7029
# Epoch 8: val_loss did not improve from -0.74395
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 161s 2s/step - binary_accuracy: 0.9945 - dice_coef: 0.6995 - iou: 0.5462 - loss: -0.7028 - val_binary_accuracy: 0.9937 - val_dice_coef: 0.6943 - val_iou: 0.5438 - val_loss: -0.6847
# Epoch 9/61
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.9943 - dice_coef: 0.6913 - iou: 0.5372 - loss: -0.6950
# Epoch 9: val_loss improved from -0.74395 to -0.77772, saving model to unet_brain_mri_seg.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 162s 2s/step - binary_accuracy: 0.9943 - dice_coef: 0.6915 - iou: 0.5373 - loss: -0.6951 - val_binary_accuracy: 0.9956 - val_dice_coef: 0.7493 - val_iou: 0.6193 - val_loss: -0.7777
# Epoch 10/61
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.9948 - dice_coef: 0.7131 - iou: 0.5688 - loss: -0.7179
# Epoch 10: val_loss did not improve from -0.77772
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 200s 2s/step - binary_accuracy: 0.9948 - dice_coef: 0.7131 - iou: 0.5688 - loss: -0.7179 - val_binary_accuracy: 0.9956 - val_dice_coef: 0.7173 - val_iou: 0.5692 - val_loss: -0.7263
# Epoch 11/61
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.9952 - dice_coef: 0.7400 - iou: 0.5927 - loss: -0.7398
# Epoch 11: val_loss did not improve from -0.77772
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 202s 2s/step - binary_accuracy: 0.9952 - dice_coef: 0.7401 - iou: 0.5928 - loss: -0.7398 - val_binary_accuracy: 0.9955 - val_dice_coef: 0.7781 - val_iou: 0.6431 - val_loss: -0.7733
# Epoch 12/61
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.9952 - dice_coef: 0.7300 - iou: 0.5863 - loss: -0.7274
# Epoch 12: val_loss did not improve from -0.77772
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 202s 2s/step - binary_accuracy: 0.9952 - dice_coef: 0.7301 - iou: 0.5865 - loss: -0.7276 - val_binary_accuracy: 0.9953 - val_dice_coef: 0.6983 - val_iou: 0.5480 - val_loss: -0.6874
# Epoch 13/61
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.9950 - dice_coef: 0.7554 - iou: 0.6137 - loss: -0.7537
# Epoch 13: val_loss did not improve from -0.77772
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 160s 2s/step - binary_accuracy: 0.9950 - dice_coef: 0.7554 - iou: 0.6137 - loss: -0.7537 - val_binary_accuracy: 0.9952 - val_dice_coef: 0.7686 - val_iou: 0.6295 - val_loss: -0.7629
# Epoch 14/61
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.9951 - dice_coef: 0.7294 - iou: 0.5805 - loss: -0.7294
# Epoch 14: val_loss did not improve from -0.77772
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 202s 2s/step - binary_accuracy: 0.9951 - dice_coef: 0.7294 - iou: 0.5805 - loss: -0.7294 - val_binary_accuracy: 0.9954 - val_dice_coef: 0.7817 - val_iou: 0.6489 - val_loss: -0.7734
# Epoch 15/61
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.9956 - dice_coef: 0.7614 - iou: 0.6217 - loss: -0.7598
# Epoch 15: val_loss did not improve from -0.77772
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 202s 2s/step - binary_accuracy: 0.9956 - dice_coef: 0.7613 - iou: 0.6215 - loss: -0.7596 - val_binary_accuracy: 0.9951 - val_dice_coef: 0.7541 - val_iou: 0.6110 - val_loss: -0.7483
# Epoch 16/61
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.9953 - dice_coef: 0.7584 - iou: 0.6175 - loss: -0.7600
# Epoch 16: val_loss did not improve from -0.77772
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 202s 2s/step - binary_accuracy: 0.9953 - dice_coef: 0.7584 - iou: 0.6175 - loss: -0.7600 - val_binary_accuracy: 0.9932 - val_dice_coef: 0.4760 - val_iou: 0.3276 - val_loss: -0.4614
# Epoch 17/61
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.9954 - dice_coef: 0.7593 - iou: 0.6179 - loss: -0.7582
# Epoch 17: val_loss improved from -0.77772 to -0.80284, saving model to unet_brain_mri_seg.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 165s 2s/step - binary_accuracy: 0.9954 - dice_coef: 0.7595 - iou: 0.6181 - loss: -0.7584 - val_binary_accuracy: 0.9965 - val_dice_coef: 0.8041 - val_iou: 0.6782 - val_loss: -0.8028
# Epoch 18/61
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.9958 - dice_coef: 0.7762 - iou: 0.6400 - loss: -0.7771
# Epoch 18: val_loss did not improve from -0.80284
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 197s 2s/step - binary_accuracy: 0.9958 - dice_coef: 0.7762 - iou: 0.6400 - loss: -0.7770 - val_binary_accuracy: 0.9926 - val_dice_coef: 0.4838 - val_iou: 0.3362 - val_loss: -0.4626
# Epoch 19/61
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.9961 - dice_coef: 0.7928 - iou: 0.6614 - loss: -0.7928
# Epoch 19: val_loss did not improve from -0.80284
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 202s 2s/step - binary_accuracy: 0.9961 - dice_coef: 0.7927 - iou: 0.6614 - loss: -0.7927 - val_binary_accuracy: 0.9962 - val_dice_coef: 0.8095 - val_iou: 0.6866 - val_loss: -0.8021
# Epoch 20/61
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.9961 - dice_coef: 0.7851 - iou: 0.6525 - loss: -0.7846
# Epoch 20: val_loss did not improve from -0.80284
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 160s 2s/step - binary_accuracy: 0.9961 - dice_coef: 0.7852 - iou: 0.6526 - loss: -0.7846 - val_binary_accuracy: 0.9956 - val_dice_coef: 0.7278 - val_iou: 0.5781 - val_loss: -0.7212
# Epoch 21/61
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.9957 - dice_coef: 0.7868 - iou: 0.6548 - loss: -0.7861
# Epoch 21: val_loss improved from -0.80284 to -0.80720, saving model to unet_brain_mri_seg.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 167s 2s/step - binary_accuracy: 0.9957 - dice_coef: 0.7869 - iou: 0.6549 - loss: -0.7862 - val_binary_accuracy: 0.9966 - val_dice_coef: 0.8072 - val_iou: 0.6807 - val_loss: -0.8072
# Epoch 22/61
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.9962 - dice_coef: 0.7905 - iou: 0.6591 - loss: -0.7912
# Epoch 22: val_loss improved from -0.80720 to -0.82043, saving model to unet_brain_mri_seg.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 166s 2s/step - binary_accuracy: 0.9962 - dice_coef: 0.7905 - iou: 0.6592 - loss: -0.7912 - val_binary_accuracy: 0.9965 - val_dice_coef: 0.8215 - val_iou: 0.6993 - val_loss: -0.8204
# Epoch 23/61
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.9961 - dice_coef: 0.8004 - iou: 0.6734 - loss: -0.7997
# Epoch 23: val_loss did not improve from -0.82043
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 160s 2s/step - binary_accuracy: 0.9961 - dice_coef: 0.8005 - iou: 0.6735 - loss: -0.7997 - val_binary_accuracy: 0.9959 - val_dice_coef: 0.7601 - val_iou: 0.6194 - val_loss: -0.7597
# Epoch 24/61
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.9959 - dice_coef: 0.7891 - iou: 0.6623 - loss: -0.7910
# Epoch 24: val_loss did not improve from -0.82043
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 202s 2s/step - binary_accuracy: 0.9959 - dice_coef: 0.7891 - iou: 0.6623 - loss: -0.7910 - val_binary_accuracy: 0.9955 - val_dice_coef: 0.7561 - val_iou: 0.6151 - val_loss: -0.7528
# Epoch 25/61
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.9965 - dice_coef: 0.7931 - iou: 0.6682 - loss: -0.7944
# Epoch 25: val_loss improved from -0.82043 to -0.82171, saving model to unet_brain_mri_seg.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 165s 2s/step - binary_accuracy: 0.9965 - dice_coef: 0.7933 - iou: 0.6685 - loss: -0.7946 - val_binary_accuracy: 0.9967 - val_dice_coef: 0.7922 - val_iou: 0.6800 - val_loss: -0.8217
# Epoch 26/61
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.9964 - dice_coef: 0.8085 - iou: 0.6835 - loss: -0.8077
# Epoch 26: val_loss did not improve from -0.82171
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 196s 2s/step - binary_accuracy: 0.9964 - dice_coef: 0.8085 - iou: 0.6834 - loss: -0.8077 - val_binary_accuracy: 0.9963 - val_dice_coef: 0.8122 - val_iou: 0.6888 - val_loss: -0.8086
# Epoch 27/61
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.9964 - dice_coef: 0.8135 - iou: 0.6897 - loss: -0.8126
# Epoch 27: val_loss did not improve from -0.82171
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 160s 2s/step - binary_accuracy: 0.9964 - dice_coef: 0.8135 - iou: 0.6897 - loss: -0.8126 - val_binary_accuracy: 0.9964 - val_dice_coef: 0.8004 - val_iou: 0.6737 - val_loss: -0.8024
# Epoch 28/61
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.9968 - dice_coef: 0.8313 - iou: 0.7143 - loss: -0.8313
# Epoch 28: val_loss improved from -0.82171 to -0.84017, saving model to unet_brain_mri_seg.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 169s 2s/step - binary_accuracy: 0.9968 - dice_coef: 0.8314 - iou: 0.7144 - loss: -0.8314 - val_binary_accuracy: 0.9971 - val_dice_coef: 0.8330 - val_iou: 0.7190 - val_loss: -0.8402
# Epoch 29/61
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.9968 - dice_coef: 0.8326 - iou: 0.7195 - loss: -0.8327
# Epoch 29: val_loss did not improve from -0.84017
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 191s 2s/step - binary_accuracy: 0.9968 - dice_coef: 0.8325 - iou: 0.7193 - loss: -0.8325 - val_binary_accuracy: 0.9948 - val_dice_coef: 0.7702 - val_iou: 0.6325 - val_loss: -0.7675
# Epoch 30/61
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.9967 - dice_coef: 0.8282 - iou: 0.7115 - loss: -0.8283
# Epoch 30: val_loss did not improve from -0.84017
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 160s 2s/step - binary_accuracy: 0.9967 - dice_coef: 0.8282 - iou: 0.7115 - loss: -0.8283 - val_binary_accuracy: 0.9958 - val_dice_coef: 0.7613 - val_iou: 0.6223 - val_loss: -0.7569
# Epoch 31/61
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.9969 - dice_coef: 0.8419 - iou: 0.7315 - loss: -0.8422
# Epoch 31: val_loss did not improve from -0.84017
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 159s 2s/step - binary_accuracy: 0.9969 - dice_coef: 0.8419 - iou: 0.7314 - loss: -0.8422 - val_binary_accuracy: 0.9966 - val_dice_coef: 0.7912 - val_iou: 0.6764 - val_loss: -0.8125
# Epoch 32/61
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.9970 - dice_coef: 0.8409 - iou: 0.7319 - loss: -0.8406
# Epoch 32: val_loss did not improve from -0.84017
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 159s 2s/step - binary_accuracy: 0.9970 - dice_coef: 0.8409 - iou: 0.7319 - loss: -0.8406 - val_binary_accuracy: 0.9966 - val_dice_coef: 0.7991 - val_iou: 0.6706 - val_loss: -0.8041
# Epoch 33/61
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.9971 - dice_coef: 0.8321 - iou: 0.7161 - loss: -0.8314
# Epoch 33: val_loss did not improve from -0.84017
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 202s 2s/step - binary_accuracy: 0.9971 - dice_coef: 0.8322 - iou: 0.7162 - loss: -0.8315 - val_binary_accuracy: 0.9943 - val_dice_coef: 0.7389 - val_iou: 0.6032 - val_loss: -0.7510
# Epoch 34/61
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.9964 - dice_coef: 0.8122 - iou: 0.6892 - loss: -0.8117
# Epoch 34: val_loss improved from -0.84017 to -0.85306, saving model to unet_brain_mri_seg.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 207s 2s/step - binary_accuracy: 0.9964 - dice_coef: 0.8122 - iou: 0.6892 - loss: -0.8117 - val_binary_accuracy: 0.9971 - val_dice_coef: 0.8587 - val_iou: 0.7570 - val_loss: -0.8531
# Epoch 35/61
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.9972 - dice_coef: 0.8609 - iou: 0.7592 - loss: -0.8603
# Epoch 35: val_loss did not improve from -0.85306
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 196s 2s/step - binary_accuracy: 0.9972 - dice_coef: 0.8609 - iou: 0.7592 - loss: -0.8603 - val_binary_accuracy: 0.9973 - val_dice_coef: 0.8316 - val_iou: 0.7200 - val_loss: -0.8449
# Epoch 36/61
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.9970 - dice_coef: 0.8339 - iou: 0.7195 - loss: -0.8352
# Epoch 36: val_loss did not improve from -0.85306
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 202s 2s/step - binary_accuracy: 0.9970 - dice_coef: 0.8340 - iou: 0.7196 - loss: -0.8352 - val_binary_accuracy: 0.9958 - val_dice_coef: 0.7739 - val_iou: 0.6400 - val_loss: -0.7680
# Epoch 37/61
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.9970 - dice_coef: 0.8448 - iou: 0.7345 - loss: -0.8445
# Epoch 37: val_loss improved from -0.85306 to -0.86300, saving model to unet_brain_mri_seg.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 171s 2s/step - binary_accuracy: 0.9970 - dice_coef: 0.8448 - iou: 0.7344 - loss: -0.8445 - val_binary_accuracy: 0.9973 - val_dice_coef: 0.8657 - val_iou: 0.7662 - val_loss: -0.8630
# Epoch 38/61
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.9971 - dice_coef: 0.8522 - iou: 0.7459 - loss: -0.8518
# Epoch 38: val_loss did not improve from -0.86300
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 159s 2s/step - binary_accuracy: 0.9971 - dice_coef: 0.8522 - iou: 0.7460 - loss: -0.8518 - val_binary_accuracy: 0.9969 - val_dice_coef: 0.8379 - val_iou: 0.7261 - val_loss: -0.8313
# Epoch 39/61
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.9972 - dice_coef: 0.8490 - iou: 0.7424 - loss: -0.8494
# Epoch 39: val_loss improved from -0.86300 to -0.86674, saving model to unet_brain_mri_seg.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 208s 2s/step - binary_accuracy: 0.9972 - dice_coef: 0.8491 - iou: 0.7425 - loss: -0.8494 - val_binary_accuracy: 0.9974 - val_dice_coef: 0.8697 - val_iou: 0.7726 - val_loss: -0.8667
# Epoch 40/61
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.9974 - dice_coef: 0.8483 - iou: 0.7409 - loss: -0.8486
# Epoch 40: val_loss did not improve from -0.86674
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 196s 2s/step - binary_accuracy: 0.9974 - dice_coef: 0.8483 - iou: 0.7409 - loss: -0.8486 - val_binary_accuracy: 0.9973 - val_dice_coef: 0.8612 - val_iou: 0.7600 - val_loss: -0.8595
# Epoch 41/61
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.9975 - dice_coef: 0.8582 - iou: 0.7560 - loss: -0.8582
# Epoch 41: val_loss improved from -0.86674 to -0.87247, saving model to unet_brain_mri_seg.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 166s 2s/step - binary_accuracy: 0.9975 - dice_coef: 0.8583 - iou: 0.7561 - loss: -0.8583 - val_binary_accuracy: 0.9976 - val_dice_coef: 0.8750 - val_iou: 0.7796 - val_loss: -0.8725
# Epoch 42/61
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.9975 - dice_coef: 0.8641 - iou: 0.7643 - loss: -0.8640
# Epoch 42: val_loss did not improve from -0.87247
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 159s 2s/step - binary_accuracy: 0.9975 - dice_coef: 0.8641 - iou: 0.7643 - loss: -0.8640 - val_binary_accuracy: 0.9971 - val_dice_coef: 0.8439 - val_iou: 0.7320 - val_loss: -0.8439
# Epoch 43/61
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.9972 - dice_coef: 0.8540 - iou: 0.7484 - loss: -0.8550
# Epoch 43: val_loss did not improve from -0.87247
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 159s 2s/step - binary_accuracy: 0.9972 - dice_coef: 0.8541 - iou: 0.7485 - loss: -0.8551 - val_binary_accuracy: 0.9975 - val_dice_coef: 0.8734 - val_iou: 0.7795 - val_loss: -0.8712
# Epoch 44/61
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.9971 - dice_coef: 0.8302 - iou: 0.7256 - loss: -0.8297
# Epoch 44: val_loss did not improve from -0.87247
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 202s 2s/step - binary_accuracy: 0.9971 - dice_coef: 0.8302 - iou: 0.7255 - loss: -0.8297 - val_binary_accuracy: 0.9973 - val_dice_coef: 0.8574 - val_iou: 0.7563 - val_loss: -0.8530
# Epoch 45/61
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.9970 - dice_coef: 0.8363 - iou: 0.7244 - loss: -0.8365
# Epoch 45: val_loss did not improve from -0.87247
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 202s 2s/step - binary_accuracy: 0.9970 - dice_coef: 0.8363 - iou: 0.7244 - loss: -0.8365 - val_binary_accuracy: 0.9964 - val_dice_coef: 0.8268 - val_iou: 0.7106 - val_loss: -0.8197
# Epoch 46/61
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.9972 - dice_coef: 0.8608 - iou: 0.7581 - loss: -0.8604
# Epoch 46: val_loss improved from -0.87247 to -0.87507, saving model to unet_brain_mri_seg.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 213s 2s/step - binary_accuracy: 0.9972 - dice_coef: 0.8607 - iou: 0.7580 - loss: -0.8604 - val_binary_accuracy: 0.9975 - val_dice_coef: 0.8739 - val_iou: 0.7792 - val_loss: -0.8751
# Epoch 47/61
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.9973 - dice_coef: 0.8598 - iou: 0.7566 - loss: -0.8597
# Epoch 47: val_loss did not improve from -0.87507
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 159s 2s/step - binary_accuracy: 0.9973 - dice_coef: 0.8598 - iou: 0.7565 - loss: -0.8597 - val_binary_accuracy: 0.9961 - val_dice_coef: 0.7803 - val_iou: 0.6484 - val_loss: -0.7733
# Epoch 48/61
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.9974 - dice_coef: 0.8655 - iou: 0.7664 - loss: -0.8653
# Epoch 48: val_loss improved from -0.87507 to -0.87984, saving model to unet_brain_mri_seg.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 215s 2s/step - binary_accuracy: 0.9974 - dice_coef: 0.8655 - iou: 0.7663 - loss: -0.8652 - val_binary_accuracy: 0.9978 - val_dice_coef: 0.8788 - val_iou: 0.7878 - val_loss: -0.8798
# Epoch 49/61
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.9975 - dice_coef: 0.8721 - iou: 0.7759 - loss: -0.8718
# Epoch 49: val_loss did not improve from -0.87984
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 189s 2s/step - binary_accuracy: 0.9975 - dice_coef: 0.8720 - iou: 0.7758 - loss: -0.8718 - val_binary_accuracy: 0.9976 - val_dice_coef: 0.8591 - val_iou: 0.7571 - val_loss: -0.8656
# Epoch 50/61
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.9974 - dice_coef: 0.8607 - iou: 0.7590 - loss: -0.8606
# Epoch 50: val_loss did not improve from -0.87984
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 202s 2s/step - binary_accuracy: 0.9974 - dice_coef: 0.8608 - iou: 0.7591 - loss: -0.8606 - val_binary_accuracy: 0.9973 - val_dice_coef: 0.8773 - val_iou: 0.7840 - val_loss: -0.8739
# Epoch 51/61
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.9977 - dice_coef: 0.8740 - iou: 0.7792 - loss: -0.8739
# Epoch 51: val_loss did not improve from -0.87984
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 159s 2s/step - binary_accuracy: 0.9977 - dice_coef: 0.8740 - iou: 0.7792 - loss: -0.8739 - val_binary_accuracy: 0.9974 - val_dice_coef: 0.8545 - val_iou: 0.7622 - val_loss: -0.8699
# Epoch 52/61
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.9976 - dice_coef: 0.8735 - iou: 0.7784 - loss: -0.8736
# Epoch 52: val_loss did not improve from -0.87984
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 202s 2s/step - binary_accuracy: 0.9976 - dice_coef: 0.8735 - iou: 0.7783 - loss: -0.8735 - val_binary_accuracy: 0.9976 - val_dice_coef: 0.8806 - val_iou: 0.7886 - val_loss: -0.8792
# Epoch 53/61
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.9972 - dice_coef: 0.8454 - iou: 0.7378 - loss: -0.8454
# Epoch 53: val_loss did not improve from -0.87984
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 202s 2s/step - binary_accuracy: 0.9972 - dice_coef: 0.8453 - iou: 0.7377 - loss: -0.8453 - val_binary_accuracy: 0.9958 - val_dice_coef: 0.7793 - val_iou: 0.6467 - val_loss: -0.7756
# Epoch 54/61
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.9970 - dice_coef: 0.8416 - iou: 0.7313 - loss: -0.8418
# Epoch 54: val_loss did not improve from -0.87984
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 202s 2s/step - binary_accuracy: 0.9970 - dice_coef: 0.8417 - iou: 0.7315 - loss: -0.8419 - val_binary_accuracy: 0.9973 - val_dice_coef: 0.8743 - val_iou: 0.7800 - val_loss: -0.8691
# Epoch 55/61
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.9975 - dice_coef: 0.8685 - iou: 0.7708 - loss: -0.8684
# Epoch 55: val_loss improved from -0.87984 to -0.88598, saving model to unet_brain_mri_seg.keras
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 210s 2s/step - binary_accuracy: 0.9975 - dice_coef: 0.8686 - iou: 0.7708 - loss: -0.8684 - val_binary_accuracy: 0.9979 - val_dice_coef: 0.8905 - val_iou: 0.8053 - val_loss: -0.8860
# Epoch 56/61
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.9974 - dice_coef: 0.8560 - iou: 0.7519 - loss: -0.8557
# Epoch 56: val_loss did not improve from -0.88598
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 194s 2s/step - binary_accuracy: 0.9974 - dice_coef: 0.8561 - iou: 0.7520 - loss: -0.8557 - val_binary_accuracy: 0.9972 - val_dice_coef: 0.8748 - val_iou: 0.7805 - val_loss: -0.8698
# Epoch 57/61
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.9976 - dice_coef: 0.8743 - iou: 0.7787 - loss: -0.8742
# Epoch 57: val_loss did not improve from -0.88598
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 202s 2s/step - binary_accuracy: 0.9976 - dice_coef: 0.8743 - iou: 0.7788 - loss: -0.8742 - val_binary_accuracy: 0.9975 - val_dice_coef: 0.8460 - val_iou: 0.7446 - val_loss: -0.8635
# Epoch 58/61
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.9972 - dice_coef: 0.8581 - iou: 0.7554 - loss: -0.8583
# Epoch 58: val_loss did not improve from -0.88598
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 159s 2s/step - binary_accuracy: 0.9972 - dice_coef: 0.8581 - iou: 0.7554 - loss: -0.8584 - val_binary_accuracy: 0.9972 - val_dice_coef: 0.8479 - val_iou: 0.7404 - val_loss: -0.8464
# Epoch 59/61
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.9974 - dice_coef: 0.8604 - iou: 0.7588 - loss: -0.8613
# Epoch 59: val_loss did not improve from -0.88598
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 158s 2s/step - binary_accuracy: 0.9974 - dice_coef: 0.8603 - iou: 0.7588 - loss: -0.8613 - val_binary_accuracy: 0.9976 - val_dice_coef: 0.8703 - val_iou: 0.7737 - val_loss: -0.8697
# Epoch 60/61
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.9975 - dice_coef: 0.8709 - iou: 0.7741 - loss: -0.8708
# Epoch 60: val_loss did not improve from -0.88598
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 202s 2s/step - binary_accuracy: 0.9975 - dice_coef: 0.8710 - iou: 0.7742 - loss: -0.8708 - val_binary_accuracy: 0.9976 - val_dice_coef: 0.8720 - val_iou: 0.7764 - val_loss: -0.8747
# Epoch 61/61
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - binary_accuracy: 0.9977 - dice_coef: 0.8839 - iou: 0.7941 - loss: -0.8838
# Epoch 61: val_loss did not improve from -0.88598
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 202s 2s/step - binary_accuracy: 0.9977 - dice_coef: 0.8838 - iou: 0.7939 - loss: -0.8837 - val_binary_accuracy: 0.9967 - val_dice_coef: 0.8402 - val_iou: 0.7271 - val_loss: -0.8434

# %% [markdown]
# # Validating the model 👀

# %% [markdown]
# * Analyzing model learning

# %%
a = history.history

list_traindice = a['dice_coef']
list_testdice = a['val_dice_coef']

list_trainjaccard = a['iou']
list_testjaccard = a['val_iou']

list_trainloss = a['loss']
list_testloss = a['val_loss']
plt.figure(1)
plt.plot(list_testloss, 'b-')
plt.plot(list_trainloss,'r-')
plt.xlabel('iteration')
plt.ylabel('loss')
plt.title('loss graph', fontsize = 15)
plt.figure(2)
plt.plot(list_traindice, 'r-')
plt.plot(list_testdice, 'b-')
plt.xlabel('iteration')
plt.ylabel('accuracy')
plt.title('accuracy graph (DICE)', fontsize = 15)
plt.figure(3)
plt.plot(list_trainjaccard, 'r-')
plt.plot(list_testjaccard, 'b-')
plt.xlabel('iteration')
plt.ylabel('accuracy')
plt.title('accuracy graph (IOU)', fontsize = 15)
plt.show()
# Red = Training
# Blue = Validation

# %% [markdown]
# * Using the model in a test set

# %%
test_gen = train_generator(df_test, BATCH_SIZE,
                                dict(),
                                target_size=(im_height, im_width))
results = model.evaluate(test_gen, steps=len(df_test) // BATCH_SIZE)
print("Test lost: ",results[0])
print("Test IOU: ",results[1])
print("Test Dice Coefficent: ",results[2])
# Out:
# Found 393 validated image filenames.
# Found 393 validated image filenames.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 673ms/step - binary_accuracy: 0.9956 - dice_coef: 0.8177 - iou: 0.6933 - loss: -0.8177
# Test lost:  -0.8296540379524231
# Test IOU:  0.9958400726318359
# Test Dice Coefficent:  0.7108938694000244

# %% [markdown]
# * Testing on some samples

# %%
for i in range(30):
    index=np.random.randint(1,len(df_test.index))
    img = cv2.imread(df_test['filename'].iloc[index])
    img = cv2.resize(img ,(im_height, im_width))
    img = img / 255
    img = img[np.newaxis, :, :, :]
    pred=model.predict(img)

    plt.figure(figsize=(12,12))
    plt.subplot(1,3,1)
    plt.imshow(np.squeeze(img))
    plt.title('Original Image')
    plt.subplot(1,3,2)
    plt.imshow(np.squeeze(cv2.imread(df_test['mask'].iloc[index])))
    plt.title('Original Mask')
    plt.subplot(1,3,3)
    plt.imshow(np.squeeze(pred) > .5)
    plt.title('Prediction')
    plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # References
#
# 1.   RONNEBERGER, O.; FISCHER, P.; BROX, T. U-Net: Convolutional Networks for Biomedical Image Segmentation. arXiv preprint arXiv:1505.04597, 2015.
#
# 2.   Zheng, P., Zhu, X. & Guo, W. Brain tumour segmentation based on an improved U-Net. BMC Med Imaging 22, 199 (2022).
